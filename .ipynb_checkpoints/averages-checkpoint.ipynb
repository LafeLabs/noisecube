# %%
import json
from urllib.request import urlopen
import json
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
data_url = "

first_scan = json.load(urlopen(frequency_sweep_json['scans'][0]))
